# %%
import turtle
t = turtle.Turtle()
canh = 50
di_chuyen= 5
canh_thay_doi = 6
di_chuyen_thay_doi = 2
goc_vuong = 90
goc_thay_doi = 18
#Hình vuông 1
t.pencolor()
t.forward(canh)
t.left(goc_vuong)
t.forward(canh)
t.left(goc_vuong)
t.forward(canh)
t.left(goc_vuong)
t.forward(canh)
canh += canh_thay_doi
#Hình vuông 2
t.left(180-goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 3
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 4
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 5
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 6
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 7
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 8
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 9
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 10
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 11
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 12
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 13
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 14
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 15
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 16
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 17
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 18
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 19
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 20
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 21
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 22
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 23
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 24
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 25
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
#Hình vuông 26
t.right(90+goc_thay_doi)
t.penup()
t.forward(di_chuyen)
t.pendown()
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
canh+=canh_thay_doi
di_chuyen+=di_chuyen_thay_doi
turtle.done()
