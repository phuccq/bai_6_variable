# %%
import turtle
t = turtle.Turtle()
canh = 100
goc_vuong = 90
goc_thay_doi = 18
#Hình vuông 1
t.forward(canh)
t.left(goc_vuong)
t.forward(canh)
t.left(goc_vuong)
t.forward(canh)
t.left(goc_vuong)
t.forward(canh)
#Hình vuông 2
t.backward(canh/2)
t.left(180+goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 3
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 4
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 5
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 6
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 7
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 8
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 9
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 10
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 11
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 12
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 13
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 14
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 15
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 16
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 17
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 18
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 19
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
#Hình vuông 20
t.backward(canh/2)
t.left(goc_thay_doi)
t.forward(canh/2)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
t.right(goc_vuong)
t.forward(canh)
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-aff9092f6cf7> in <module>
#      79 t.forward(canh)
#      80 t.right(goc_vuong)
# ---> 81 t.forward(canh)
#      82 t.right(goc_vuong)
#      83 t.forward(canh)
#
# ~\anaconda3\lib\turtle.py in forward(self, distance)
#    1636         (-50.00,0.00)
#    1637         """
# -> 1638         self._go(distance)
#    1639
#    1640     def back(self, distance):
#
# ~\anaconda3\lib\turtle.py in _go(self, distance)
#    1604         """move turtle forward by specified distance"""
#    1605         ende = self._position + self._orient * distance
# -> 1606         self._goto(ende)
#    1607
#    1608     def _rotate(self, angle):
#
# ~\anaconda3\lib\turtle.py in _goto(self, end)
#    3175                 self._position = start + delta * n
#    3176                 if self._drawing:
# ...
